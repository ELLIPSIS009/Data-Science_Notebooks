# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('NSE-TATAGLOBAL.csv')
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  28-09-2018  234.05  235.95  230.20  233.50  233.75               3069914
# 1  27-09-2018  234.55  236.80  231.10  233.80  233.25               5082859
# 2  26-09-2018  240.00  240.00  232.50  235.00  234.25               2240909
# 3  25-09-2018  233.30  236.75  232.00  236.25  236.10               2349368
# 4  24-09-2018  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
training_set = data.iloc[:, 1:2].values
training_set[0:10]
# Out:
# array([[234.05],
#        [234.55],
#        [240.  ],
#        [233.3 ],
#        [233.55],
#        [235.  ],
#        [235.95],
#        [237.9 ],
#        [233.15],
#        [223.45]])

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)
training_set_scaled[0:10]
# Out:
# array([[0.6202352 ],
#        [0.62226277],
#        [0.64436334],
#        [0.61719384],
#        [0.61820762],
#        [0.62408759],
#        [0.62793998],
#        [0.63584753],
#        [0.61658556],
#        [0.57725061]])

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# !pip install tensorflow

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 8s 55ms/step - loss: 0.0108
# Epoch 2/100
# 62/62 [==============================] - 3s 55ms/step - loss: 0.0031
# Epoch 3/100
# 62/62 [==============================] - 3s 56ms/step - loss: 0.0028
# Epoch 4/100
# 62/62 [==============================] - 3s 56ms/step - loss: 0.0026
# Epoch 5/100
# 62/62 [==============================] - 3s 55ms/step - loss: 0.0024
# Epoch 6/100
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0024
# Epoch 7/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0022
# Epoch 8/100
# 62/62 [==============================] - 3s 56ms/step - loss: 0.0020
# Epoch 9/100
# 62/62 [==============================] - 4s 60ms/step - loss: 0.0018
# Epoch 10/100
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0022
# Epoch 11/100
# 62/62 [==============================] - 4s 64ms/step - loss: 0.0019
# Epoch 12/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0019
# Epoch 13/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0017
# Epoch 15/100
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0017
# Epoch 16/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0016
# Epoch 17/100
# 62/62 [==============================] - 4s 58ms/step - loss: 0.0015
# Epoch 18/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0014
# Epoch 19/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0017
# Epoch 20/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0014
# Epoch 21/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0014
# Epoch 22/100
# 62/62 [==============================] - 4s 59ms/step - loss: 0.0013
# Epoch 23/100
# 62/62 [==============================] - 4s 60ms/step - loss: 0.0013
# Epoch 24/100
# 62/62 [==============================] - 4s 61ms/step - loss: 0.0012
# Epoch 25/100
# 62/62 [==============================] - 4s 62ms/step - loss: 0.0012
# Epoch 26/100
# 62/62 [==============================] - 4s 60ms/step - loss: 0.0014
# Epoch 27/100
# 62/62 [==============================] - 4s 60ms/step - loss: 0.0013
# Epoch 67/100
# 62/62 [==============================] - 4s 64ms/step - loss: 7.8722e-04
# Epoch 68/100
# 62/62 [==============================] - 4s 64ms/step - loss: 6.9970e-04
# Epoch 69/100
# 62/62 [==============================] - 4s 63ms/step - loss: 8.1957e-04
# Epoch 70/100
# 62/62 [==============================] - 4s 63ms/step - loss: 7.1068e-04
# Epoch 71/100
# 62/62 [==============================] - 4s 64ms/step - loss: 8.4261e-04
# Epoch 72/100
# 62/62 [==============================] - 4s 67ms/step - loss: 7.6310e-04
# Epoch 73/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.7597e-04
# Epoch 74/100
# 62/62 [==============================] - 4s 71ms/step - loss: 6.8374e-04
# Epoch 75/100
# 62/62 [==============================] - 5s 77ms/step - loss: 7.4916e-04
# Epoch 76/100
# 62/62 [==============================] - 5s 76ms/step - loss: 7.5472e-04
# Epoch 77/100
# 62/62 [==============================] - 5s 76ms/step - loss: 7.2217e-04
# Epoch 78/100
# 62/62 [==============================] - 4s 62ms/step - loss: 6.8586e-04
# Epoch 79/100
# 62/62 [==============================] - 4s 63ms/step - loss: 6.7576e-04
# Epoch 80/100
# 62/62 [==============================] - 4s 70ms/step - loss: 7.5786e-04
# Epoch 81/100
# 62/62 [==============================] - 5s 76ms/step - loss: 6.5559e-04
# Epoch 82/100
# 62/62 [==============================] - 4s 70ms/step - loss: 7.7984e-04
# Epoch 83/100
# 62/62 [==============================] - 4s 62ms/step - loss: 6.1476e-04
# Epoch 84/100
# 62/62 [==============================] - 4s 63ms/step - loss: 7.1165e-04
# Epoch 85/100
# 62/62 [==============================] - 5s 75ms/step - loss: 6.7519e-04
# Epoch 86/100
# 62/62 [==============================] - 5s 79ms/step - loss: 6.4569e-04
# Epoch 87/100
# 62/62 [==============================] - 4s 67ms/step - loss: 6.6189e-04
# Epoch 88/100
# 62/62 [==============================] - 4s 65ms/step - loss: 7.7678e-04
# Epoch 89/100
# 62/62 [==============================] - 4s 68ms/step - loss: 6.9594e-04
# Epoch 90/100
# 62/62 [==============================] - 5s 77ms/step - loss: 6.1181e-04
# Epoch 91/100
# 62/62 [==============================] - 5s 74ms/step - loss: 6.3938e-04
# Epoch 92/100
# 62/62 [==============================] - 4s 63ms/step - loss: 6.2452e-04
# Epoch 93/100
# 62/62 [==============================] - 4s 65ms/step - loss: 6.7151e-04
# Epoch 94/100
# 62/62 [==============================] - 5s 76ms/step - loss: 6.6759e-04
# Epoch 95/100
# 62/62 [==============================] - 5s 78ms/step - loss: 6.0377e-04
# Epoch 96/100
# 62/62 [==============================] - 4s 67ms/step - loss: 6.7806e-04
# Epoch 97/100
# 62/62 [==============================] - 4s 63ms/step - loss: 6.5577e-04
# Epoch 98/100
# 62/62 [==============================] - 4s 63ms/step - loss: 6.3360e-04
# Epoch 99/100
# 62/62 [==============================] - 5s 77ms/step - loss: 6.0034e-04
# Epoch 100/100
# 62/62 [==============================] - 5s 77ms/step - loss: 6.0069e-04

# %%
real_stock_price = data.iloc[:, 1:2].values
real_stock_price[0:10]
# Out:
# array([[234.05],
#        [234.55],
#        [240.  ],
#        [233.3 ],
#        [233.55],
#        [235.  ],
#        [235.95],
#        [237.9 ],
#        [233.15],
#        [223.45]])

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
