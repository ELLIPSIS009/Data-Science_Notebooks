# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
data = pd.read_csv('NSE-TATAGLOBAL.csv')
data.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  28-09-2018  234.05  235.95  230.20  233.50  233.75               3069914
# 1  27-09-2018  234.55  236.80  231.10  233.80  233.25               5082859
# 2  26-09-2018  240.00  240.00  232.50  235.00  234.25               2240909
# 3  25-09-2018  233.30  236.75  232.00  236.25  236.10               2349368
# 4  24-09-2018  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %%
training_set = data.iloc[:, 1:2].values
training_set[0:10]
# Out:
# array([[234.05],
#        [234.55],
#        [240.  ],
#        [233.3 ],
#        [233.55],
#        [235.  ],
#        [235.95],
#        [237.9 ],
#        [233.15],
#        [223.45]])

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)
training_set_scaled[0:10]
# Out:
# array([[0.6202352 ],
#        [0.62226277],
#        [0.64436334],
#        [0.61719384],
#        [0.61820762],
#        [0.62408759],
#        [0.62793998],
#        [0.63584753],
#        [0.61658556],
#        [0.57725061]])

# %%
X_train = []
y_train = []
for i in range(60, 2035):
    X_train.append(training_set_scaled[i-60:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# !pip install tensorflow

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 9s 68ms/step - loss: 0.0119
# Epoch 2/100
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0033
# Epoch 3/100
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0027
# Epoch 4/100
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0027
# Epoch 5/100
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0024
# Epoch 6/100
# 62/62 [==============================] - 4s 67ms/step - loss: 0.0022
# Epoch 7/100
# 62/62 [==============================] - 4s 69ms/step - loss: 0.0022
# Epoch 8/100
# 62/62 [==============================] - 4s 69ms/step - loss: 0.0022
# Epoch 9/100
# 62/62 [==============================] - 4s 69ms/step - loss: 0.0020
# Epoch 10/100
# 62/62 [==============================] - 5s 86ms/step - loss: 0.0021
# Epoch 11/100
# 62/62 [==============================] - 7s 105ms/step - loss: 0.0017
# Epoch 12/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0018
# Epoch 13/100
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0017
# Epoch 14/100
# 62/62 [==============================] - 9s 148ms/step - loss: 0.0015
# Epoch 15/100
# 62/62 [==============================] - 7s 106ms/step - loss: 0.0018
# Epoch 16/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.0017
# Epoch 17/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0015
# Epoch 18/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0015
# Epoch 19/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0013
# Epoch 20/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0014
# Epoch 21/100
# 62/62 [==============================] - 7s 105ms/step - loss: 0.0014
# Epoch 22/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.0014
# Epoch 23/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0015
# Epoch 24/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0014
# Epoch 25/100
# 62/62 [==============================] - 6s 104ms/step - loss: 0.0014
# Epoch 26/100
# 62/62 [==============================] - 6s 101ms/step - loss: 0.0012
# Epoch 27/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0012
# Epoch 28/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0013
# Epoch 29/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0013
# Epoch 30/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0013
# Epoch 31/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0011
# Epoch 32/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0013
# Epoch 33/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0011
# Epoch 34/100
# 62/62 [==============================] - 6s 101ms/step - loss: 0.0011
# Epoch 35/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0012
# Epoch 36/100
# 62/62 [==============================] - 6s 102ms/step - loss: 9.8142e-04
# Epoch 37/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0011
# Epoch 38/100
# 62/62 [==============================] - 6s 101ms/step - loss: 0.0011
# Epoch 39/100
# 62/62 [==============================] - 6s 102ms/step - loss: 0.0010
# Epoch 40/100
# 62/62 [==============================] - 6s 102ms/step - loss: 9.5442e-04
# Epoch 41/100
# 62/62 [==============================] - 6s 103ms/step - loss: 9.3579e-04
# Epoch 42/100
# 62/62 [==============================] - 7s 107ms/step - loss: 9.3127e-04
# Epoch 43/100
# 62/62 [==============================] - 7s 110ms/step - loss: 0.0010
# Epoch 44/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0010
# Epoch 45/100
# 62/62 [==============================] - 6s 101ms/step - loss: 9.3144e-04
# Epoch 46/100
# 62/62 [==============================] - 6s 103ms/step - loss: 0.0010 1s - loss:  - ETA: 0s - loss
# Epoch 47/100
# 62/62 [==============================] - 6s 97ms/step - loss: 8.1413e-04
# Epoch 48/100
# 62/62 [==============================] - 6s 99ms/step - loss: 9.2827e-04
# Epoch 49/100
# 62/62 [==============================] - 6s 99ms/step - loss: 9.6781e-04: 0s - loss: 9.6781e-0
# Epoch 50/100
# 62/62 [==============================] - 6s 98ms/step - loss: 9.3527e-04
# Epoch 51/100
# 62/62 [==============================] - 6s 101ms/step - loss: 8.2437e-04
# Epoch 52/100
# 62/62 [==============================] - 6s 95ms/step - loss: 8.8489e-04
# Epoch 53/100
# 62/62 [==============================] - 6s 96ms/step - loss: 9.2067e-04
# Epoch 54/100
# 62/62 [==============================] - 6s 96ms/step - loss: 8.7091e-04
# Epoch 55/100
# 62/62 [==============================] - 6s 92ms/step - loss: 0.0010: 1s -
# Epoch 56/100
# 62/62 [==============================] - 6s 98ms/step - loss: 8.4533e-04
# Epoch 57/100
# 62/62 [==============================] - 6s 97ms/step - loss: 8.0860e-04
# Epoch 58/100
# 62/62 [==============================] - 6s 96ms/step - loss: 7.9937e-04
# Epoch 59/100
# 62/62 [==============================] - 6s 90ms/step - loss: 7.3040e-04
# Epoch 60/100
# 62/62 [==============================] - 6s 97ms/step - loss: 8.2341e-04
# Epoch 61/100
# 62/62 [==============================] - 6s 92ms/step - loss: 9.6326e-04
# Epoch 62/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.4166e-04: 0s - loss: 7
# Epoch 63/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.8444e-04
# Epoch 64/100
# 62/62 [==============================] - 6s 96ms/step - loss: 7.0682e-04: 1s - lo
# Epoch 65/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.0045e-04
# Epoch 66/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.4346e-04
# Epoch 67/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.8679e-04
# Epoch 68/100
# 62/62 [==============================] - 6s 99ms/step - loss: 7.9298e-04
# Epoch 69/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.2273e-04
# Epoch 70/100
# 62/62 [==============================] - 6s 91ms/step - loss: 8.0465e-04
# Epoch 71/100
# 62/62 [==============================] - 6s 91ms/step - loss: 8.0537e-04
# Epoch 72/100
# 62/62 [==============================] - 6s 100ms/step - loss: 8.0554e-04
# Epoch 73/100
# 62/62 [==============================] - 6s 90ms/step - loss: 7.1837e-04
# Epoch 74/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.7030e-04
# Epoch 75/100
# 62/62 [==============================] - 6s 98ms/step - loss: 8.8962e-04
# Epoch 76/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.2346e-04
# Epoch 77/100
# 62/62 [==============================] - 6s 96ms/step - loss: 7.1058e-04
# Epoch 78/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.7815e-04
# Epoch 79/100
# 62/62 [==============================] - 6s 97ms/step - loss: 8.3537e-04: 1s -
# Epoch 80/100
# 62/62 [==============================] - 6s 98ms/step - loss: 6.7523e-04: 0s - loss: 6.6
# Epoch 81/100
# 62/62 [==============================] - 6s 93ms/step - loss: 6.2991e-04
# Epoch 82/100
# 62/62 [==============================] - 6s 89ms/step - loss: 6.0950e-04
# Epoch 83/100
# 62/62 [==============================] - 6s 96ms/step - loss: 7.8397e-04
# Epoch 84/100
# 62/62 [==============================] - 6s 99ms/step - loss: 6.2391e-04
# Epoch 85/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.9476e-04
# Epoch 86/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.2587e-04
# Epoch 87/100
# 62/62 [==============================] - 6s 95ms/step - loss: 6.6718e-04
# Epoch 88/100
# 62/62 [==============================] - 6s 92ms/step - loss: 6.7807e-04: 0s - loss:
# Epoch 89/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.1393e-04: 3s - los - ETA: 2s - loss: 6.9870e-0 - ETA
# Epoch 90/100
# 62/62 [==============================] - 6s 97ms/step - loss: 5.9654e-04
# Epoch 91/100
# 62/62 [==============================] - 6s 97ms/step - loss: 5.6536e-04
# Epoch 92/100
# 62/62 [==============================] - 6s 90ms/step - loss: 7.2002e-04
# Epoch 93/100
# 62/62 [==============================] - 6s 99ms/step - loss: 6.2447e-04
# Epoch 94/100
# 62/62 [==============================] - 6s 97ms/step - loss: 6.3506e-04
# Epoch 95/100
# 62/62 [==============================] - 6s 97ms/step - loss: 6.4649e-04
# Epoch 96/100
# 62/62 [==============================] - 5s 87ms/step - loss: 6.4003e-04
# Epoch 97/100
# 62/62 [==============================] - 6s 93ms/step - loss: 6.6871e-04
# Epoch 98/100
# 62/62 [==============================] - 6s 103ms/step - loss: 5.5977e-04
# Epoch 99/100
# 62/62 [==============================] - 6s 98ms/step - loss: 7.6987e-04
# Epoch 100/100
# 62/62 [==============================] - 6s 97ms/step - loss: 7.2736e-04

# %%
real_stock_price = data.iloc[:, 1:2].values
real_stock_price[0:10]
# Out:
# array([[234.05],
#        [234.55],
#        [240.  ],
#        [233.3 ],
#        [233.55],
#        [235.  ],
#        [235.95],
#        [237.9 ],
#        [233.15],
#        [223.45]])

# %%
dataset_total = pd.concat((data['Open'], data['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(data) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
    X_test.append(inputs[i-60:i, 0])
    X_test = np.array(X_test)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5568/3349472046.py in <module>
#       5 X_test = []
#       6 for i in range(60, 76):
# ----> 7     X_test.append(inputs[i-60:i, 0])
#       8     X_test = np.array(X_test)
#       9     X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'
